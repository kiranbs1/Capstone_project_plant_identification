# %% [markdown]
# Where the model will be trained, this will be a demo

# %%
# !pip install tensorflow==2.15.0
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.15.0 (from versions: 2.16.0rc0, 2.16.1)
# ERROR: No matching distribution found for tensorflow==2.15.0
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
import os
import heapq

# %% [markdown]
# Numpy - used for mathmatical functions such as np.argmax()
# Tensorflow - The machine learning framework that will be used for this project. Also gives access tf datasets
# Tensorflow.Keras - The interface API for tensorflow for easy building/training of models
# Matplotlib - plotting libary, used to display our data when giving examples

# %%
BATCH_SIZE = 32
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "training data/modified105Flowers",
    shuffle=True,
    color_mode='rgb',
    labels='inferred',
    image_size=(256,256),
    batch_size = BATCH_SIZE
)
class_names = dataset.class_names
class_names
# Out:
# Found 8914 files belonging to 105 classes.
# ['alpine sea holly',
#  'anthurium',
#  'artichoke',
#  'azalea',
#  'ball moss',
#  'balloon flower',
#  'barbeton daisy',
#  'bearded iris',
#  'bee balm',
#  'bird of paradise',
#  'bishop of llandaff',
#  'black-eyed susan',
#  'blackberry lily',
#  'blanket flower',
#  'bolero deep blue',
#  'bougainvillea',
#  'bromelia',
#  'buttercup',
#  'californian poppy',
#  'camellia',
#  'canna lily',
#  'canterbury bells',
#  'cape flower',
#  'carnation',
#  'cautleya spicata',
#  'clematis',
#  "colt's foot",
#  'columbine',
#  'common dandelion',
#  'corn poppy',
#  'cyclamen',
#  'daffodil',
#  'daisy',
#  'dandelion',
#  'desert-rose',
#  'english marigold',
#  'fire lily',
#  'foxglove',
#  'frangipani',
#  'fritillary',
#  'garden phlox',
#  'gaura',
#  'gazania',
#  'geranium',
#  'giant white arum lily',
#  'globe thistle',
#  'globe-flower',
#  'grape hyacinth',
#  'great masterwort',
#  'hard-leaved pocket orchid',
#  'hibiscus',
#  'hippeastrum',
#  'japanese anemone',
#  'king protea',
#  'lenten rose',
#  'lotus',
#  'love in the mist',
#  'magnolia',
#  'mallow',
#  'marigold',
#  'mexican aster',
#  'mexican petunia',
#  'monkshood',
#  'moon orchid',
#  'morning glory',
#  'orange dahlia',
#  'osteospermum',
#  'oxeye daisy',
#  'passion flower',
#  'pelargonium',
#  'peruvian lily',
#  'petunia',
#  'pincushion flower',
#  'pink primrose',
#  'pink-yellow dahlia',
#  'poinsettia',
#  'primula',
#  'prince of wales feathers',
#  'purple coneflower',
#  'red ginger',
#  'rose',
#  'ruby-lipped cattleya',
#  'siam tulip',
#  'silverbush',
#  'snapdragon',
#  'spear thistle',
#  'spring crocus',
#  'stemless gentian',
#  'sunflower',
#  'sweet pea',
#  'sweet william',
#  'sword lily',
#  'thorn apple',
#  'tiger lily',
#  'toad lily',
#  'tree mallow',
#  'tree poppy',
#  'trumpet creeper',
#  'tulip',
#  'wallflower',
#  'water lily',
#  'watercress',
#  'wild pansy',
#  'windflower',
#  'yellow iris']

# %% [markdown]
# Creates a dataset from the folders in a given folder. Grabs data from "training data/flowers", then shuffles the images and for variation, defines the image input size and resizes automatically and then sets the batch size.
# Images are sent to be trained in batches of 32 allowing for greater memory efficiency, Parallelism and better results through increasing variance allowing model to escape local minimums.

# %%
def get_datasets(ds) :
    train_percent = .8
    train_size = int(len(ds)*train_percent)
    train_ds = ds.take(train_size)
    test_percent = .1
    test_size = int(len(ds)*test_percent)
    test_ds = ds.skip(train_size).take(test_size)
    val_ds = ds.skip(train_size).skip(test_size)
    train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
    test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
    val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
    return train_ds, test_ds, val_ds

# %% [markdown]
# Defines the partitions for the different datasets that will be used. 80% of data will be used to train, 10% will be used to validate training during training by the model and another 10% will be used to test the model after training. A testing dataset is particularly important as the model has never seen any of this data, and can't be biased towards it.

# %%
train_ds, test_ds, val_ds = get_datasets(dataset)
print(len(train_ds))
print(len(test_ds))
print(len(val_ds))
# Out:
# 223
# 27
# 29

# %% [markdown]
# gets the datasets from get_datasets(). Then cache the dataset into memory and prefetches the data to overlap data preprocessing and model execution times for faster training. tf.data.AUTOTUNE is used to automatically tune the buffer size based on available system resources

# %%
augment_images = Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal"),
    layers.experimental.preprocessing.RandomRotation(.2),
    layers.experimental.preprocessing.Rescaling(1.0/255),
    layers.experimental.preprocessing.RandomContrast(0.2)
])
# Out:
# WARNING:tensorflow:From C:\Users\kiran\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %% [markdown]
# augment_images will be run on the training data but NOT the real input data to be predicted.
# layers.experimental.preprocessing.RandomFlip("horizontal") -
# Randomly flips the input imaes horizontally with a 50% probabilityH helps the model become invariant to horizontal fli while also increasing variance in training datap
#
# layers.experimental.preprocessing.RandomRotation(.2) -
# Randomly rotates the input imaes by a factor of 0in radias). The rotation is applied randomly within the specified rang Helps the model become tolerant to picture rotation also increases variance in training data.
#
# layers.experimental.preprocessing.Resizing(256, 256) -
# Resizes the input images to a fixed size of 256x256 pixels. This ensures that all images in the dataset have the same dimensions
# layers.experimental.preprocessing.Rescaling(1.0/255) -
# Rescales the pixel values of the imaebetweento the ran of 0 - 11]B brings pixel values into a range that is more suitable for training.layers.experimental.preprocessing.RandomContrast(0.2) -
# Randomly adjusts the contrast of the input imae Helps the model become tolerant to high or low contrast, also increases variance in training data.nt
# .
# e.s.

# %%
input_shape = (BATCH_SIZE, 256, 256, 3)
model = models.Sequential([
    augment_images,
    layers.Conv2D(64,(3,3), activation='relu', input_shape=(256,256)),
    layers.MaxPooling2D(),
    layers.Conv2D(64,(5,5), activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32,(5,5), activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32,(3,3), activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64,(3,3), activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.Dense(len(class_names), activation='softmax')
])
model.build(input_shape=input_shape)

# %% [markdown]
# input_shape = (BATCH_SIZE, 256, 256, 3) - Defines the input shape for the model. It indicates that each input batch will have dimensions (batch size, height, width, channels), where height and width are 256 pixels, and there are 3 channels (for RGB color images).
# models.Sequential - Creates a sequential model, which allows you to build a linear stack of layers.
# augment_images - Calls the above method to augment the data training the model.
# layers.Conv2D(64, (3,3), activation='relu', input_shape=(256,256)) -
# Convolutional layer with 64 filters, each of size (3,3), using the ReLU activation function. This is the first convolutional layer in the model, and it takes the input shape specified by (256, 256, 3
# layers.MaxPooling2D() -
# Max pooling layer with default pool size (2,2). It reduces the spatial dimensions of the representation, helping to reduce computation and improve translation invariancelayers.Flatten() -
# Flattens the input to a one-dimensional array. This is necessary before connecting to dense laye
# layers.Dense(256, activation='relu') -
# Fully connected (dense) layer with 256 units and ReLU activation functiolayers.Dense(len(class_names), activation='softmax') -
# Output layer with as many units as there are classes (specified by len(class_names)) anuses d softmax activation function. It produces probabilities for each class, and the class with the highest probability is predicted.ns.
# .).

# %% [markdown]
# Different activation layers I might use (https://keras.io/api/layers/activation_layers/)-
# ReLU (Rectified Linear Unit) - ReLU is one of the most widely used activation functions. ReLU introduces non-linearity allowing it to represent complex patterns (like different petals) while also being computationally very cheap.
#     - formula
#         - f(x)=max(0,x)
# Softmax - Softmax is used in the output layer of multi-class classification models. It converts the model outputs into probabilities, the sum of probabilities across all classes is 1. Each output represents the chance that the input belongs to a certain class.
#     - formula
#         - exp_x = exp(x - max(x))
#
# f(x) = exp_x / sum(exp_x
# Leaky ReL - similar to Relu but helps mitigate the "dying ReLU" problem, where neurons can become inactive during training by allowing a non-zero gradient when the input is negative. May implement if I believe that dying ReLu is a problem.
#       -formula
#         - f(x) = alpha * x if x < 0
#
# f(x) = x if x >= 0)      - f(x)=max(0,x)
#  PReLU is similar to Leaky ReLU but allows the slope of the negative part to be learned during training. It provides more flexibility in capturing complex patterns. May implement if I believe that dying ReLu is a problem.
# PReLU (Parametric ReLU) -
#  f(x) = alpha * x for x < 0
#
# f(x) = x for x
# >=
#         - f(x)=max(0,x)

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 256, 256, 3)       0
#
#  conv2d_12 (Conv2D)          (32, 252, 252, 64)        4864
#
#  max_pooling2d_10 (MaxPooli  (32, 126, 126, 64)        0
#  ng2D)
#
#  conv2d_13 (Conv2D)          (32, 122, 122, 64)        102464
#
#  max_pooling2d_11 (MaxPooli  (32, 61, 61, 64)          0
#  ng2D)
#
#  conv2d_14 (Conv2D)          (32, 57, 57, 32)          51232
#
#  max_pooling2d_12 (MaxPooli  (32, 28, 28, 32)          0
#  ng2D)
#
#  conv2d_15 (Conv2D)          (32, 26, 26, 32)          9248
#
#  max_pooling2d_13 (MaxPooli  (32, 13, 13, 32)          0
#  ng2D)
#
#  flatten_3 (Flatten)         (32, 5408)                0
#
#  dense_6 (Dense)             (32, 128)                 692352
#
#  dense_7 (Dense)             (32, 105)                 13545
#
# =================================================================
# Total params: 873705 (3.33 MB)
# Trainable params: 873705 (3.33 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %% [markdown]
# .compile configures the model for training setting up key parameters.
# optimizer='adam' - adam Algorithm is one of the most popular optimisers that adapts the learning rates for each parameter individually
# The loss function is a measure of how well the model is performing during training. It shows the error between the predicted values and the actual values.
# SparseCategoricalCrossentrop  iis often used for multi-class classification problem like thiss where the labels are integer.
# from_logits=False means that the input to the loss function is expected to be probability values, where each value represents the predicted probability of belonging to a specific class
# Metrics are used to evaluate the performance of the model during and after training. 'accuracy' is a common metric for classification problems, showing the ratio of correctly classified sampless

# %%
    model.fit(
        train_ds,
        batch_size=BATCH_SIZE,
        validation_data=val_ds,
        verbose=1,
        epochs=50
    )
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\kiran\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\kiran\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 223/223 [==============================] - 783s 3s/step - loss: 4.2971 - accuracy: 0.0499 - val_loss: 4.0050 - val_accuracy: 0.0919
# Epoch 2/50
# 223/223 [==============================] - 704s 3s/step - loss: 3.8291 - accuracy: 0.1008 - val_loss: 3.6034 - val_accuracy: 0.1543
# Epoch 3/50
# 223/223 [==============================] - 693s 3s/step - loss: 3.3885 - accuracy: 0.1675 - val_loss: 3.2505 - val_accuracy: 0.1915
# Epoch 4/50
# 223/223 [==============================] - 682s 3s/step - loss: 3.0568 - accuracy: 0.2294 - val_loss: 2.8564 - val_accuracy: 0.2856
# Epoch 5/50
# 223/223 [==============================] - 688s 3s/step - loss: 2.7512 - accuracy: 0.2904 - val_loss: 2.7569 - val_accuracy: 0.3151
# Epoch 6/50
# 223/223 [==============================] - 695s 3s/step - loss: 2.5405 - accuracy: 0.3292 - val_loss: 2.4549 - val_accuracy: 0.3786
# Epoch 7/50
# 223/223 [==============================] - 700s 3s/step - loss: 2.4022 - accuracy: 0.3673 - val_loss: 2.4330 - val_accuracy: 0.3731
# Epoch 8/50
# 223/223 [==============================] - 691s 3s/step - loss: 2.2405 - accuracy: 0.4053 - val_loss: 2.2811 - val_accuracy: 0.4168
# Epoch 9/50
# 223/223 [==============================] - 696s 3s/step - loss: 2.0857 - accuracy: 0.4351 - val_loss: 2.3375 - val_accuracy: 0.3840
# Epoch 10/50
# 223/223 [==============================] - 688s 3s/step - loss: 1.9948 - accuracy: 0.4580 - val_loss: 2.1543 - val_accuracy: 0.4540
# Epoch 11/50
# 223/223 [==============================] - 688s 3s/step - loss: 1.8959 - accuracy: 0.4867 - val_loss: 2.1624 - val_accuracy: 0.4475
# Epoch 12/50
# 223/223 [==============================] - 696s 3s/step - loss: 1.8585 - accuracy: 0.4950 - val_loss: 2.1052 - val_accuracy: 0.4639
# Epoch 13/50
# 223/223 [==============================] - 686s 3s/step - loss: 1.7318 - accuracy: 0.5227 - val_loss: 2.0164 - val_accuracy: 0.4562
# Epoch 14/50
# 223/223 [==============================] - 688s 3s/step - loss: 1.6588 - accuracy: 0.5364 - val_loss: 2.0584 - val_accuracy: 0.4737
# Epoch 15/50
# 223/223 [==============================] - 684s 3s/step - loss: 1.6177 - accuracy: 0.5504 - val_loss: 2.0428 - val_accuracy: 0.4639
# Epoch 16/50
# 223/223 [==============================] - 698s 3s/step - loss: 1.5567 - accuracy: 0.5705 - val_loss: 1.9986 - val_accuracy: 0.5033
# Epoch 17/50
# 223/223 [==============================] - 694s 3s/step - loss: 1.4794 - accuracy: 0.5852 - val_loss: 1.9335 - val_accuracy: 0.4967
# Epoch 18/50
# 223/223 [==============================] - 691s 3s/step - loss: 1.4676 - accuracy: 0.5919 - val_loss: 1.9725 - val_accuracy: 0.4902
# Epoch 19/50
# 223/223 [==============================] - 691s 3s/step - loss: 1.4084 - accuracy: 0.5989 - val_loss: 1.9225 - val_accuracy: 0.5153
# Epoch 20/50
# 223/223 [==============================] - 691s 3s/step - loss: 1.3924 - accuracy: 0.6101 - val_loss: 1.9553 - val_accuracy: 0.5044
# Epoch 21/50
# 223/223 [==============================] - 689s 3s/step - loss: 1.3252 - accuracy: 0.6205 - val_loss: 1.9491 - val_accuracy: 0.5175
# Epoch 22/50
# 223/223 [==============================] - 684s 3s/step - loss: 1.3122 - accuracy: 0.6246 - val_loss: 1.8464 - val_accuracy: 0.5306
# Epoch 23/50
# 223/223 [==============================] - 691s 3s/step - loss: 1.2684 - accuracy: 0.6351 - val_loss: 1.8439 - val_accuracy: 0.5438
# Epoch 24/50
# 223/223 [==============================] - 687s 3s/step - loss: 1.2583 - accuracy: 0.6397 - val_loss: 1.8541 - val_accuracy: 0.5328
# Epoch 25/50
# 223/223 [==============================] - 683s 3s/step - loss: 1.2041 - accuracy: 0.6574 - val_loss: 1.9457 - val_accuracy: 0.5383
# Epoch 26/50
# 223/223 [==============================] - 690s 3s/step - loss: 1.1848 - accuracy: 0.6522 - val_loss: 1.8778 - val_accuracy: 0.5678
# Epoch 27/50
# 223/223 [==============================] - 685s 3s/step - loss: 1.1629 - accuracy: 0.6666 - val_loss: 1.8778 - val_accuracy: 0.5449
# Epoch 28/50
# 223/223 [==============================] - 687s 3s/step - loss: 1.1559 - accuracy: 0.6635 - val_loss: 1.8346 - val_accuracy: 0.5514
# Epoch 29/50
# 223/223 [==============================] - 687s 3s/step - loss: 1.1104 - accuracy: 0.6797 - val_loss: 1.8920 - val_accuracy: 0.5328
# Epoch 30/50
# 223/223 [==============================] - 697s 3s/step - loss: 1.0990 - accuracy: 0.6844 - val_loss: 1.8154 - val_accuracy: 0.5635
# Epoch 31/50
# 223/223 [==============================] - 695s 3s/step - loss: 1.0924 - accuracy: 0.6855 - val_loss: 1.7585 - val_accuracy: 0.5832
# Epoch 32/50
# 223/223 [==============================] - 708s 3s/step - loss: 1.0445 - accuracy: 0.6925 - val_loss: 1.8486 - val_accuracy: 0.5558
# Epoch 33/50
# 223/223 [==============================] - 701s 3s/step - loss: 1.0536 - accuracy: 0.6930 - val_loss: 1.9526 - val_accuracy: 0.5503
# Epoch 34/50
# 223/223 [==============================] - 715s 3s/step - loss: 1.0251 - accuracy: 0.7038 - val_loss: 1.8657 - val_accuracy: 0.5853
# Epoch 35/50
# 223/223 [==============================] - 699s 3s/step - loss: 1.0043 - accuracy: 0.7053 - val_loss: 1.8483 - val_accuracy: 0.5613
# Epoch 36/50
# 223/223 [==============================] - 700s 3s/step - loss: 0.9953 - accuracy: 0.7061 - val_loss: 1.9015 - val_accuracy: 0.5635
# Epoch 37/50
# 223/223 [==============================] - 701s 3s/step - loss: 0.9364 - accuracy: 0.7248 - val_loss: 1.8332 - val_accuracy: 0.6039
# Epoch 38/50
# 223/223 [==============================] - 698s 3s/step - loss: 0.9353 - accuracy: 0.7209 - val_loss: 1.8773 - val_accuracy: 0.5930
# Epoch 39/50
# 223/223 [==============================] - 781s 4s/step - loss: 0.9388 - accuracy: 0.7147 - val_loss: 1.8612 - val_accuracy: 0.5689
# Epoch 40/50
# 223/223 [==============================] - 816s 4s/step - loss: 0.9461 - accuracy: 0.7183 - val_loss: 1.8147 - val_accuracy: 0.5886
# Epoch 41/50
# 223/223 [==============================] - 759s 3s/step - loss: 0.8758 - accuracy: 0.7340 - val_loss: 1.8377 - val_accuracy: 0.5952
# Epoch 42/50
# 223/223 [==============================] - 820s 4s/step - loss: 0.9087 - accuracy: 0.7319 - val_loss: 2.0213 - val_accuracy: 0.5613
# Epoch 43/50
# 223/223 [==============================] - 800s 4s/step - loss: 0.8897 - accuracy: 0.7363 - val_loss: 1.9661 - val_accuracy: 0.5799
# Epoch 44/50
# 223/223 [==============================] - 826s 4s/step - loss: 0.8927 - accuracy: 0.7351 - val_loss: 1.7874 - val_accuracy: 0.6028
# Epoch 45/50
# 223/223 [==============================] - 829s 4s/step - loss: 0.8659 - accuracy: 0.7451 - val_loss: 1.8352 - val_accuracy: 0.5875
# Epoch 46/50
# 223/223 [==============================] - 748s 3s/step - loss: 0.8652 - accuracy: 0.7431 - val_loss: 1.7960 - val_accuracy: 0.5897
# Epoch 47/50
# 223/223 [==============================] - 759s 3s/step - loss: 0.8571 - accuracy: 0.7483 - val_loss: 1.7805 - val_accuracy: 0.5853
# Epoch 48/50
# 223/223 [==============================] - 831s 4s/step - loss: 0.8361 - accuracy: 0.7532 - val_loss: 1.8545 - val_accuracy: 0.5864
# Epoch 49/50
# 223/223 [==============================] - 767s 3s/step - loss: 0.8251 - accuracy: 0.7514 - val_loss: 1.8040 - val_accuracy: 0.6105
# Epoch 50/50
# 137/223 [=================>............] - ETA: 4:40 - loss: 0.7769 - accuracy: 0.7632Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\kiran\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\kiran\AppData\Local\Temp\ipykernel_30284\2193019030.py", line 1, in <module>
#   File "C:\Users\kiran\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\utils\traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "C:\Users\kiran\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\eager\context.py", line 1415, in get_graph_debug_info
#     pywrap_tfe.TFE_ContextGetGraphDebugInfo(self._handle, name, buffer_)
# MemoryError: bad allocation
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\kiran\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\interactiveshell.py", line 2144, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "C:\Users\kiran\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\kiran\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\kiran\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\kiran\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\ultratb.py", line 1063, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#   File "C:\Users\kiran\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\ultratb.py", line 1160, in get_records
#     res = list(stack_data.FrameInfo.stack_data(etb, options=options))[tb_offset:]
#   File "C:\Users\kiran\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\stack_data\core.py", line 597, in stack_data
#     yield from collapse_repeated(
#   File "C:\Users\kiran\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\stack_data\utils.py", line 83, in collapse_repeated
#     yield from map(mapper, original_group)
#   File "C:\Users\kiran\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\stack_data\core.py", line 587, in mapper
#     return cls(f, options)
#   File "C:\Users\kiran\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\stack_data\core.py", line 551, in __init__
#     self.executing = Source.executing(frame_or_tb)
#   File "C:\Users\kiran\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\executing\executing.py", line 264, in executing
#   File "C:\Users\kiran\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\executing\executing.py", line 183, in for_frame
#     return cls.for_filename(frame.f_code.co_filename, frame.f_globals or {}, use_cache)
#   File "C:\Users\kiran\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\executing\executing.py", line 212, in for_filename
#     return cls._for_filename_and_lines(filename, tuple(lines))
#   File "C:\Users\kiran\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\executing\executing.py", line 223, in _for_filename_and_lines
#     result = source_cache[(filename, lines)] = cls(filename, lines)
#   File "C:\Users\kiran\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\executing\executing.py", line 163, in __init__
#     self.tree = ast.parse(self.text, filename=filename)
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\ast.py", line 50, in parse
#     return compile(source, filename, mode, flags,
# MemoryError

# %% [markdown]
# model.fit trains the model based on the given parameters.
# train.ds - training dataset
# batch_size - number of samples in each batch
# validation_data - used to test against the model during training as a unseen set of samples
# verbos=1 - enables a progress bar that shows the training progress for each epoch
# epochs - The number of times the entire training dataset is passed through the neural network

# %%
model.evaluate(test_ds)
# Out:
# 27/27 [==============================] - 26s 708ms/step - loss: 1.8133 - accuracy: 0.6134
# [1.813270092010498, 0.6134259104728699]

# %% [markdown]
# model.evaluate(test_ds) - tests the model after training against a dataset that the model hasn't seen, this data was split off before the data was trained

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]

    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
for images_batch, labels_batch in test_ds.take(1):
    
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    
    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])
    
    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
    print(np.argmax(batch_prediction[0]))
    print([f"{value * 100:.6f}%" for value in batch_prediction[0]])
    print(class_names)
# Out:
# first image to predict
# actual label: mallow
# 1/1 [==============================] - 2s 2s/step
# predicted label: lenten rose
# 54
# ['0.000000%', '0.292231%', '0.000000%', '0.000000%', '0.000000%', '0.000000%', '0.000005%', '0.000001%', '0.000000%', '0.000000%', '0.000000%', '0.000000%', '0.000000%', '0.000000%', '0.000961%', '0.783019%', '0.000003%', '0.000000%', '0.000514%', '0.169801%', '0.000000%', '0.002613%', '0.000000%', '0.000001%', '0.000001%', '0.000720%', '0.000000%', '0.000541%', '0.000000%', '0.000000%', '0.000008%', '0.000006%', '0.000092%', '0.000000%', '0.000000%', '0.000000%', '0.000000%', '0.069643%', '0.194432%', '0.000000%', '0.000000%', '0.000000%', '0.000000%', '0.000000%', '0.000022%', '0.000000%', '0.000000%', '0.000000%', '0.000000%', '0.014458%', '0.000119%', '0.000005%', '0.097651%', '0.000000%', '90.958554%', '0.109251%', '0.000000%', '0.000000%', '1.164908%', '0.000000%', '0.000000%', '0.000000%', '0.000000%', '0.000002%', '0.000003%', '0.000000%', '0.000000%', '0.000000%', '0.000031%', '0.000009%', '0.000296%', '5.749282%', '0.000000%', '0.000006%', '0.000000%', '0.203886%', '0.125154%', '0.000000%', '0.000041%', '0.000000%', '0.032746%', '0.000002%', '0.000000%', '0.000000%', '0.007217%', '0.000000%', '0.000000%', '0.000000%', '0.000007%', '0.000000%', '0.000000%', '0.015546%', '0.000000%', '0.000000%', '0.000000%', '0.000000%', '0.000000%', '0.000000%', '0.005675%', '0.000001%', '0.000086%', '0.000016%', '0.000000%', '0.000436%', '0.000000%']
# ['alpine sea holly', 'anthurium', 'artichoke', 'azalea', 'ball moss', 'balloon flower', 'barbeton daisy', 'bearded iris', 'bee balm', 'bird of paradise', 'bishop of llandaff', 'black-eyed susan', 'blackberry lily', 'blanket flower', 'bolero deep blue', 'bougainvillea', 'bromelia', 'buttercup', 'californian poppy', 'camellia', 'canna lily', 'canterbury bells', 'cape flower', 'carnation', 'cautleya spicata', 'clematis', "colt's foot", 'columbine', 'common dandelion', 'corn poppy', 'cyclamen', 'daffodil', 'daisy', 'dandelion', 'desert-rose', 'english marigold', 'fire lily', 'foxglove', 'frangipani', 'fritillary', 'garden phlox', 'gaura', 'gazania', 'geranium', 'giant white arum lily', 'globe thistle', 'globe-flower', 'grape hyacinth', 'great masterwort', 'hard-leaved pocket orchid', 'hibiscus', 'hippeastrum', 'japanese anemone', 'king protea', 'lenten rose', 'lotus', 'love in the mist', 'magnolia', 'mallow', 'marigold', 'mexican aster', 'mexican petunia', 'monkshood', 'moon orchid', 'morning glory', 'orange dahlia', 'osteospermum', 'oxeye daisy', 'passion flower', 'pelargonium', 'peruvian lily', 'petunia', 'pincushion flower', 'pink primrose', 'pink-yellow dahlia', 'poinsettia', 'primula', 'prince of wales feathers', 'purple coneflower', 'red ginger', 'rose', 'ruby-lipped cattleya', 'siam tulip', 'silverbush', 'snapdragon', 'spear thistle', 'spring crocus', 'stemless gentian', 'sunflower', 'sweet pea', 'sweet william', 'sword lily', 'thorn apple', 'tiger lily', 'toad lily', 'tree mallow', 'tree poppy', 'trumpet creeper', 'tulip', 'wallflower', 'water lily', 'watercress', 'wild pansy', 'windflower', 'yellow iris']

# %% [markdown]
# Just shows an example of an inputted image going in, getting predicted and then being displayed

# %%
model.save(f"models/model 2 full")
# Out:
# INFO:tensorflow:Assets written to: models/model 2 full\assets
# INFO:tensorflow:Assets written to: models/model 2 full\assets

# %%
loaded_model = tf.keras.models.load_model('models/model 2 full')

# %%
loaded_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 256, 256, 3)       0
#
#  conv2d (Conv2D)             (None, 254, 254, 64)      1792
#
#  max_pooling2d (MaxPooling2  (None, 127, 127, 64)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 64)      36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 62, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 32)        18464
#
#  max_pooling2d_2 (MaxPoolin  (None, 30, 30, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 32)        9248
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 12, 12, 64)        18496
#
#  max_pooling2d_4 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 256)               590080
#
#  dense_1 (Dense)             (None, 105)               26985
#
# =================================================================
# Total params: 701993 (2.68 MB)
# Trainable params: 701993 (2.68 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
modified_105_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "training data/oxford 102 flowers",
    shuffle=True,
    color_mode='rgb',
    labels='inferred',
    image_size=(256,256),
    batch_size = BATCH_SIZE
)
dataset_class_names = modified_105_ds.class_names
# Out:
# Found 7957 files belonging to 100 classes.

# %%
loaded_model.evaluate(modified_105_ds)
# Out:
# 279/279 [==============================] - 95s 337ms/step - loss: 0.5957 - accuracy: 0.8597
# [0.5956718921661377, 0.85965895652771]

# %%
tally = 0
total = 0
for images_batch, labels_batch in modified_105_ds.take(1000):
    
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    
    batch_prediction = model.predict(images_batch)
    classified_indexes = heapq.nlargest(3, range(len(batch_prediction[0])), key=batch_prediction[0].__getitem__)
    act_label = dataset_class_names[first_label]
    predict_label = class_names[classified_indexes[0]]
    # predict_label_2 = class_names[classified_indexes[1]]
    # predict_label_3 = class_names[classified_indexes[2]]
    # print(act_label + "    " + predict_label + "    " + predict_label_2 + "    " + predict_label_3)
    print(act_label + "    " + predict_label)
    
    total += 1
    # if (act_label == predict_label) | (act_label == predict_label_2) | (act_label == predict_label_3) :
    if act_label == predict_label :
        tally += 1
print("Oxford 102 dataset test, top answer only")
print("accuracy : " + str(tally / total))
# Out:
# 1/1 [==============================] - 0s 341ms/step
# petunia    petunia
# 1/1 [==============================] - 0s 336ms/step
# petunia    petunia
# 1/1 [==============================] - 0s 335ms/step
# giant white arum lily    giant white arum lily
# 1/1 [==============================] - 0s 334ms/step
# moon orchid    moon orchid
# 1/1 [==============================] - 0s 442ms/step
# bishop of llandaff    bishop of llandaff
# 1/1 [==============================] - 0s 377ms/step
# californian poppy    californian poppy
# 1/1 [==============================] - 0s 345ms/step
# wallflower    wallflower
# 1/1 [==============================] - 0s 348ms/step
# blackberry lily    blackberry lily
# 1/1 [==============================] - 0s 325ms/step
# camellia    camellia
# 1/1 [==============================] - 0s 336ms/step
# morning glory    morning glory
# 1/1 [==============================] - 0s 330ms/step
# magnolia    magnolia
# 1/1 [==============================] - 0s 326ms/step
# frangipani    frangipani
# 1/1 [==============================] - 0s 330ms/step
# morning glory    morning glory
# 1/1 [==============================] - 0s 340ms/step
# japanese anemone    frangipani
# 1/1 [==============================] - 0s 330ms/step
# frangipani    frangipani
# 1/1 [==============================] - 0s 325ms/step
# garden phlox    garden phlox
# 1/1 [==============================] - 0s 370ms/step
# foxglove    foxglove
# 1/1 [==============================] - 0s 378ms/step
# wallflower    wallflower
# 1/1 [==============================] - 0s 340ms/step
# common dandelion    common dandelion
# 1/1 [==============================] - 0s 342ms/step
# snapdragon    snapdragon
# 1/1 [==============================] - 0s 348ms/step
# artichoke    artichoke
# 1/1 [==============================] - 0s 331ms/step
# water lily    water lily
# 1/1 [==============================] - 0s 325ms/step
# hard-leaved pocket orchid    hard-leaved pocket orchid
# 1/1 [==============================] - 0s 340ms/step
# gazania    gazania
# 1/1 [==============================] - 0s 438ms/step
# petunia    petunia
# 1/1 [==============================] - 0s 361ms/step
# pelargonium    pelargonium
# 1/1 [==============================] - 0s 464ms/step
# barbeton daisy    barbeton daisy
# 1/1 [==============================] - 1s 634ms/step
# orange dahlia    orange dahlia
# 1/1 [==============================] - 0s 382ms/step
# daffodil    buttercup
# 1/1 [==============================] - 0s 420ms/step
# osteospermum    osteospermum
# 1/1 [==============================] - 1s 508ms/step
# wild pansy    canterbury bells
# 1/1 [==============================] - 0s 403ms/step
# blackberry lily    blackberry lily
# 1/1 [==============================] - 0s 333ms/step
# common dandelion    common dandelion
# 1/1 [==============================] - 0s 350ms/step
# thorn apple    thorn apple
# 1/1 [==============================] - 0s 406ms/step
# pelargonium    pelargonium
# 1/1 [==============================] - 0s 350ms/step
# clematis    clematis
# 1/1 [==============================] - 1s 595ms/step
# bromelia    bromelia
# 1/1 [==============================] - 1s 616ms/step
# cyclamen    cyclamen
# 1/1 [==============================] - 0s 349ms/step
# osteospermum    osteospermum
# 1/1 [==============================] - 0s 365ms/step
# passion flower    passion flower
# 1/1 [==============================] - 0s 361ms/step
# peruvian lily    peruvian lily
# 1/1 [==============================] - 0s 365ms/step
# pink-yellow dahlia    pink-yellow dahlia
# 1/1 [==============================] - 0s 372ms/step
# love in the mist    love in the mist
# 1/1 [==============================] - 0s 363ms/step
# frangipani    frangipani
# 1/1 [==============================] - 0s 355ms/step
# petunia    petunia
# 1/1 [==============================] - 0s 367ms/step
# barbeton daisy    barbeton daisy
# 1/1 [==============================] - 0s 342ms/step
# windflower    petunia
# 1/1 [==============================] - 0s 365ms/step
# ruby-lipped cattleya    ruby-lipped cattleya
# 1/1 [==============================] - 0s 358ms/step
# gazania    gazania
# 1/1 [==============================] - 0s 354ms/step
# carnation    cyclamen
# 1/1 [==============================] - 0s 345ms/step
# azalea    azalea
# 1/1 [==============================] - 0s 354ms/step
# thorn apple    thorn apple
# 1/1 [==============================] - 0s 348ms/step
# sweet william    sweet william
# 1/1 [==============================] - 0s 347ms/step
# cape flower    cape flower
# 1/1 [==============================] - 0s 343ms/step
# sword lily    sword lily
# 1/1 [==============================] - 0s 357ms/step
# black-eyed susan    black-eyed susan
# 1/1 [==============================] - 0s 337ms/step
# mexican petunia    mexican petunia
# 1/1 [==============================] - 0s 428ms/step
# barbeton daisy    barbeton daisy
# 1/1 [==============================] - 0s 338ms/step
# poinsettia    poinsettia
# 1/1 [==============================] - 0s 345ms/step
# bird of paradise    bird of paradise
# 1/1 [==============================] - 0s 339ms/step
# great masterwort    great masterwort
# 1/1 [==============================] - 0s 342ms/step
# yellow iris    yellow iris
# 1/1 [==============================] - 0s 343ms/step
# hibiscus    hibiscus
# 1/1 [==============================] - 0s 339ms/step
# canna lily    canna lily
# 1/1 [==============================] - 0s 340ms/step
# bougainvillea    cyclamen
# 1/1 [==============================] - 0s 343ms/step
# wallflower    wallflower
# 1/1 [==============================] - 0s 341ms/step
# stemless gentian    stemless gentian
# 1/1 [==============================] - 0s 365ms/step
# azalea    azalea
# 1/1 [==============================] - 0s 347ms/step
# wallflower    wallflower
# 1/1 [==============================] - 0s 338ms/step
# bougainvillea    bougainvillea
# 1/1 [==============================] - 0s 343ms/step
# bougainvillea    petunia
# 1/1 [==============================] - 0s 338ms/step
# artichoke    artichoke
# 1/1 [==============================] - 0s 345ms/step
# blackberry lily    blackberry lily
# 1/1 [==============================] - 0s 346ms/step
# bolero deep blue    bolero deep blue
# 1/1 [==============================] - 0s 344ms/step
# lenten rose    peruvian lily
# 1/1 [==============================] - 0s 354ms/step
# bougainvillea    bougainvillea
# 1/1 [==============================] - 0s 417ms/step
# yellow iris    yellow iris
# 1/1 [==============================] - 0s 354ms/step
# blanket flower    blanket flower
# 1/1 [==============================] - 0s 342ms/step
# stemless gentian    stemless gentian
# 1/1 [==============================] - 0s 344ms/step
# giant white arum lily    giant white arum lily
# 1/1 [==============================] - 0s 342ms/step
# foxglove    foxglove
# 1/1 [==============================] - 0s 341ms/step
# primula    primula
# 1/1 [==============================] - 0s 348ms/step
# sweet william    sweet william
# 1/1 [==============================] - 0s 340ms/step
# snapdragon    snapdragon
# 1/1 [==============================] - 0s 345ms/step
# barbeton daisy    barbeton daisy
# 1/1 [==============================] - 0s 344ms/step
# wallflower    wallflower
# 1/1 [==============================] - 0s 342ms/step
# mexican petunia    mexican petunia
# 1/1 [==============================] - 0s 382ms/step
# anthurium    anthurium
# 1/1 [==============================] - 0s 341ms/step
# passion flower    passion flower
# 1/1 [==============================] - 0s 345ms/step
# oxeye daisy    oxeye daisy
# 1/1 [==============================] - 0s 346ms/step
# mexican petunia    mexican petunia
# 1/1 [==============================] - 0s 407ms/step
# snapdragon    snapdragon
# 1/1 [==============================] - 0s 344ms/step
# cyclamen    cyclamen
# 1/1 [==============================] - 0s 340ms/step
# bougainvillea    bougainvillea
# 1/1 [==============================] - 0s 347ms/step
# bird of paradise    bird of paradise
# 1/1 [==============================] - 0s 344ms/step
# thorn apple    thorn apple
# 1/1 [==============================] - 0s 344ms/step
# great masterwort    great masterwort
# 1/1 [==============================] - 0s 390ms/step
# clematis    clematis
# 1/1 [==============================] - 0s 340ms/step
# foxglove    foxglove
# 1/1 [==============================] - 0s 350ms/step
# frangipani    frangipani
# 1/1 [==============================] - 0s 382ms/step
# columbine    columbine
# 1/1 [==============================] - 0s 399ms/step
# bougainvillea    bougainvillea
# 1/1 [==============================] - 0s 416ms/step
# globe thistle    globe thistle
# 1/1 [==============================] - 0s 425ms/step
# pink-yellow dahlia    pink-yellow dahlia
# 1/1 [==============================] - 1s 549ms/step
# petunia    petunia
# 1/1 [==============================] - 1s 554ms/step
# thorn apple    thorn apple
# 1/1 [==============================] - 0s 474ms/step
# bromelia    bromelia
# 1/1 [==============================] - 1s 528ms/step
# water lily    water lily
# 1/1 [==============================] - 0s 450ms/step
# japanese anemone    japanese anemone
# 1/1 [==============================] - 0s 462ms/step
# frangipani    frangipani
# 1/1 [==============================] - 0s 366ms/step
# marigold    marigold
# 1/1 [==============================] - 0s 339ms/step
# barbeton daisy    barbeton daisy
# 1/1 [==============================] - 0s 349ms/step
# alpine sea holly    alpine sea holly
# 1/1 [==============================] - 0s 355ms/step
# hard-leaved pocket orchid    hard-leaved pocket orchid
# 1/1 [==============================] - 0s 336ms/step
# water lily    water lily
# 1/1 [==============================] - 0s 372ms/step
# daffodil    daffodil
# 1/1 [==============================] - 0s 345ms/step
# sword lily    sword lily
# 1/1 [==============================] - 0s 382ms/step
# daffodil    daffodil
# 1/1 [==============================] - 0s 387ms/step
# peruvian lily    peruvian lily
# 1/1 [==============================] - 0s 335ms/step
# alpine sea holly    alpine sea holly
# 1/1 [==============================] - 0s 367ms/step
# osteospermum    osteospermum
# 1/1 [==============================] - 0s 335ms/step
# morning glory    morning glory
# 1/1 [==============================] - 0s 350ms/step
# hippeastrum    hippeastrum
# 1/1 [==============================] - 0s 340ms/step
# wallflower    wallflower
# 1/1 [==============================] - 0s 325ms/step
# gaura    gaura
# 1/1 [==============================] - 0s 360ms/step
# sweet william    sweet william
# 1/1 [==============================] - 0s 328ms/step
# foxglove    foxglove
# 1/1 [==============================] - 0s 377ms/step
# giant white arum lily    giant white arum lily
# 1/1 [==============================] - 0s 320ms/step
# azalea    azalea
# 1/1 [==============================] - 0s 390ms/step
# osteospermum    osteospermum
# 1/1 [==============================] - 0s 330ms/step
# camellia    mallow
# 1/1 [==============================] - 0s 395ms/step
# mallow    mallow
# 1/1 [==============================] - 0s 332ms/step
# windflower    windflower
# 1/1 [==============================] - 0s 333ms/step
# hibiscus    hibiscus
# 1/1 [==============================] - 0s 330ms/step
# stemless gentian    stemless gentian
# 1/1 [==============================] - 0s 383ms/step
# bee balm    great masterwort
# 1/1 [==============================] - 0s 381ms/step
# poinsettia    poinsettia
# 1/1 [==============================] - 0s 400ms/step
# foxglove    foxglove
# 1/1 [==============================] - 0s 344ms/step
# oxeye daisy    daisy
# 1/1 [==============================] - 0s 370ms/step
# primula    primula
# 1/1 [==============================] - 0s 400ms/step
# frangipani    frangipani
# 1/1 [==============================] - 0s 360ms/step
# pelargonium    pelargonium
# 1/1 [==============================] - 0s 370ms/step
# watercress    watercress
# 1/1 [==============================] - 0s 347ms/step
# windflower    primula
# 1/1 [==============================] - 0s 325ms/step
# desert-rose    desert-rose
# 1/1 [==============================] - 0s 330ms/step
# great masterwort    great masterwort
# 1/1 [==============================] - 0s 331ms/step
# sword lily    clematis
# 1/1 [==============================] - 0s 340ms/step
# sweet william    sweet william
# 1/1 [==============================] - 0s 333ms/step
# siam tulip    siam tulip
# 1/1 [==============================] - 0s 325ms/step
# stemless gentian    mexican petunia
# 1/1 [==============================] - 0s 340ms/step
# water lily    water lily
# 1/1 [==============================] - 0s 326ms/step
# clematis    clematis
# 1/1 [==============================] - 0s 340ms/step
# wild pansy    wild pansy
# 1/1 [==============================] - 0s 338ms/step
# canna lily    cyclamen
# 1/1 [==============================] - 0s 355ms/step
# pink-yellow dahlia    pink-yellow dahlia
# 1/1 [==============================] - 0s 332ms/step
# toad lily    foxglove
# 1/1 [==============================] - 0s 360ms/step
# bougainvillea    bougainvillea
# 1/1 [==============================] - 0s 336ms/step
# grape hyacinth    grape hyacinth
# 1/1 [==============================] - 0s 363ms/step
# globe-flower    globe-flower
# 1/1 [==============================] - 0s 340ms/step
# morning glory    morning glory
# 1/1 [==============================] - 0s 340ms/step
# mallow    mallow
# 1/1 [==============================] - 0s 343ms/step
# pink-yellow dahlia    pink-yellow dahlia
# 1/1 [==============================] - 0s 421ms/step
# fritillary    fritillary
# 1/1 [==============================] - 0s 390ms/step
# fritillary    fritillary
# 1/1 [==============================] - 0s 335ms/step
# camellia    silverbush
# 1/1 [==============================] - 0s 342ms/step
# osteospermum    osteospermum
# 1/1 [==============================] - 0s 330ms/step
# buttercup    buttercup
# 1/1 [==============================] - 0s 327ms/step
# wallflower    wallflower
# 1/1 [==============================] - 0s 320ms/step
# artichoke    artichoke
# 1/1 [==============================] - 0s 323ms/step
# bishop of llandaff    bishop of llandaff
# 1/1 [==============================] - 0s 325ms/step
# pink-yellow dahlia    pink-yellow dahlia
# 1/1 [==============================] - 0s 322ms/step
# love in the mist    love in the mist
# 1/1 [==============================] - 0s 325ms/step
# petunia    petunia
# 1/1 [==============================] - 0s 335ms/step
# stemless gentian    grape hyacinth
# 1/1 [==============================] - 0s 320ms/step
# tree poppy    tree poppy
# 1/1 [==============================] - 0s 330ms/step
# californian poppy    californian poppy
# 1/1 [==============================] - 0s 326ms/step
# ruby-lipped cattleya    ruby-lipped cattleya
# 1/1 [==============================] - 0s 323ms/step
# artichoke    pincushion flower
# 1/1 [==============================] - 0s 325ms/step
# poinsettia    poinsettia
# 1/1 [==============================] - 0s 345ms/step
# marigold    marigold
# 1/1 [==============================] - 0s 335ms/step
# passion flower    passion flower
# 1/1 [==============================] - 0s 330ms/step
# cyclamen    cyclamen
# 1/1 [==============================] - 0s 330ms/step
# watercress    watercress
# 1/1 [==============================] - 0s 330ms/step
# artichoke    artichoke
# 1/1 [==============================] - 0s 340ms/step
# sweet pea    cyclamen
# 1/1 [==============================] - 0s 415ms/step
# windflower    windflower
# 1/1 [==============================] - 0s 320ms/step
# watercress    primula
# 1/1 [==============================] - 0s 410ms/step
# petunia    petunia
# 1/1 [==============================] - 0s 315ms/step
# hard-leaved pocket orchid    hard-leaved pocket orchid
# 1/1 [==============================] - 0s 350ms/step
# great masterwort    great masterwort
# 1/1 [==============================] - 0s 340ms/step
# siam tulip    siam tulip
# 1/1 [==============================] - 0s 340ms/step
# primula    primula
# 1/1 [==============================] - 0s 340ms/step
# bougainvillea    clematis
# 1/1 [==============================] - 0s 320ms/step
# artichoke    artichoke
# 1/1 [==============================] - 0s 334ms/step
# lotus    lotus
# 1/1 [==============================] - 0s 340ms/step
# tree mallow    tree mallow
# 1/1 [==============================] - 0s 360ms/step
# love in the mist    love in the mist
# 1/1 [==============================] - 0s 456ms/step
# petunia    petunia
# 1/1 [==============================] - 0s 320ms/step
# carnation    anthurium
# 1/1 [==============================] - 0s 320ms/step
# globe thistle    globe thistle
# 1/1 [==============================] - 0s 330ms/step
# spear thistle    spear thistle
# 1/1 [==============================] - 0s 318ms/step
# yellow iris    yellow iris
# 1/1 [==============================] - 0s 317ms/step
# wallflower    wallflower
# 1/1 [==============================] - 0s 335ms/step
# snapdragon    frangipani
# 1/1 [==============================] - 0s 325ms/step
# magnolia    magnolia
# 1/1 [==============================] - 0s 330ms/step
# camellia    camellia
# 1/1 [==============================] - 0s 346ms/step
# blackberry lily    blackberry lily
# 1/1 [==============================] - 0s 325ms/step
# bishop of llandaff    bishop of llandaff
# 1/1 [==============================] - 0s 338ms/step
# sweet pea    sweet pea
# 1/1 [==============================] - 0s 341ms/step
# watercress    sword lily
# 1/1 [==============================] - 0s 333ms/step
# desert-rose    desert-rose
# 1/1 [==============================] - 0s 330ms/step
# gazania    gazania
# 1/1 [==============================] - 0s 330ms/step
# watercress    watercress
# 1/1 [==============================] - 0s 320ms/step
# ruby-lipped cattleya    ruby-lipped cattleya
# 1/1 [==============================] - 0s 348ms/step
# magnolia    magnolia
# 1/1 [==============================] - 0s 325ms/step
# gazania    gazania
# 1/1 [==============================] - 0s 330ms/step
# bougainvillea    bougainvillea
# 1/1 [==============================] - 0s 326ms/step
# globe thistle    globe thistle
# 1/1 [==============================] - 0s 318ms/step
# wallflower    wallflower
# 1/1 [==============================] - 0s 326ms/step
# bee balm    water lily
# 1/1 [==============================] - 0s 320ms/step
# daffodil    daffodil
# 1/1 [==============================] - 0s 330ms/step
# geranium    barbeton daisy
# 1/1 [==============================] - 0s 330ms/step
# hibiscus    hibiscus
# 1/1 [==============================] - 0s 340ms/step
# mexican petunia    mexican petunia
# 1/1 [==============================] - 0s 333ms/step
# morning glory    morning glory
# 1/1 [==============================] - 0s 330ms/step
# clematis    clematis
# 1/1 [==============================] - 0s 330ms/step
# tree mallow    tree mallow
# 1/1 [==============================] - 0s 320ms/step
# bolero deep blue    bolero deep blue
# 1/1 [==============================] - 0s 320ms/step
# ball moss    sweet william
# 1/1 [==============================] - 0s 324ms/step
# spear thistle    spear thistle
# 1/1 [==============================] - 0s 326ms/step
# ball moss    ball moss
# 1/1 [==============================] - 0s 325ms/step
# azalea    azalea
# 1/1 [==============================] - 0s 325ms/step
# clematis    petunia
# 1/1 [==============================] - 0s 319ms/step
# windflower    frangipani
# 1/1 [==============================] - 0s 340ms/step
# purple coneflower    purple coneflower
# 1/1 [==============================] - 0s 326ms/step
# foxglove    foxglove
# 1/1 [==============================] - 0s 335ms/step
# bolero deep blue    bolero deep blue
# 1/1 [==============================] - 2s 2s/step
# sword lily    sword lily
# 1/1 [==============================] - 0s 339ms/step
# columbine    columbine
# 1/1 [==============================] - 0s 350ms/step
# trumpet creeper    trumpet creeper
# 1/1 [==============================] - 0s 373ms/step
# tiger lily    tiger lily
# 1/1 [==============================] - 0s 360ms/step
# geranium    geranium
# 1/1 [==============================] - 0s 355ms/step
# black-eyed susan    black-eyed susan
# 1/1 [==============================] - 0s 355ms/step
# daffodil    daffodil
# 1/1 [==============================] - 0s 365ms/step
# canterbury bells    canterbury bells
# 1/1 [==============================] - 0s 329ms/step
# ruby-lipped cattleya    clematis
# 1/1 [==============================] - 0s 343ms/step
# passion flower    passion flower
# 1/1 [==============================] - 0s 332ms/step
# foxglove    foxglove
# 1/1 [==============================] - 0s 260ms/step
# orange dahlia    orange dahlia
# Oxford 102 dataset test, top answer only
# accuracy : 0.8755020080321285
